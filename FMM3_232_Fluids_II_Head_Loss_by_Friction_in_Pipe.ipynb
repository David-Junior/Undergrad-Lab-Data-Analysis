# %% [markdown]
# <a href="https://colab.research.google.com/github/David-Junior/Undergrad-Lab-Data-Analysis/blob/main/FMM3_232_Fluids_II_Head_Loss_by_Friction_in_Pipe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Experimental Data
h1 = np.array([102, 100.9, 100.2, 98.8, 94.5, 93.7, 92.8, 92.5, 91.8, 92.1, 89.6, 88.5])/100 #m
h2 = np.array([71, 72.1, 72.8, 74.4, 78.1, 78.8, 79.8, 80, 80.7, 81.4, 82.9, 84])/100 #m
Vol = np.array([700, 520, 480, 440, 420, 360, 320, 320, 320, 280, 240, 220])/1000000 #m^3
t = np.array([23.5, 16.42, 16.79, 16.16, 16.61, 16.70, 17.02, 16.94, 18.42, 19.02, 16.83, 16.95]) #s

SG = 2.97
l = 2
d = 6.25/1000 #m
g = 9.81

# %%
# Analysis
hm = h1 - h2
hf = hm * (SG-1)

A = np.pi * d**2 / 4
Q = Vol / t
v = Q / A

log_hf = np.log(hf)
log_v = np.log(v)

# %%
# Analysed Data
DF = pd.DataFrame({'h1':h1, 'h2':h2, 'hm':hm, 'hf': hf, 'Vol':Vol, 'Q':Q, 'v': v, 'log(hf)': log_hf, 'log(v)': log_v})
DF
# Out:
#        h1     h2     hm       hf      Vol         Q         v   log(hf)  \
# 0   1.020  0.710  0.310  0.61070  0.00070  0.000030  0.970913 -0.493149
# 1   1.009  0.721  0.288  0.56736  0.00052  0.000032  1.032239 -0.566761
# 2   1.002  0.728  0.274  0.53978  0.00048  0.000029  0.931838 -0.616594
# 3   0.988  0.744  0.244  0.48068  0.00044  0.000027  0.887486 -0.732554
# 4   0.945  0.781  0.164  0.32308  0.00042  0.000025  0.824195 -1.129855
# 5   0.937  0.788  0.149  0.29353  0.00036  0.000022  0.702645 -1.225775
# 6   0.928  0.798  0.130  0.25610  0.00032  0.000019  0.612831 -1.362187
# 7   0.925  0.800  0.125  0.24625  0.00032  0.000019  0.615725 -1.401408
# 8   0.918  0.807  0.111  0.21867  0.00032  0.000017  0.566253 -1.520192
# 9   0.921  0.814  0.107  0.21079  0.00028  0.000015  0.479841 -1.556893
# 10  0.896  0.829  0.067  0.13199  0.00024  0.000014  0.464812 -2.025029
# 11  0.885  0.840  0.045  0.08865  0.00022  0.000013  0.423061 -2.423059
#
#       log(v)
# 0  -0.029519
# ...

# %%
plt.figure(figsize=(10, 6))
plt.scatter(log_v, log_hf, label='Data points')

# Calculate the line of best fit (gradient and y-intercept)
gradient, y_intercept = np.polyfit(log_v, log_hf, 1)

# Create the line of best fit
line_of_best_fit = gradient * log_v + y_intercept

plt.plot(log_v, line_of_best_fit, color='red', label=f'Line of best fit (y = {gradient:.2f}x + {y_intercept:.2f})')

plt.xlabel('log(v)')
plt.ylabel('log(hf)')
plt.title('log(hf) vs log(v)')
plt.grid(True)
plt.legend()
plt.show()

print(f"Gradient of the line of best fit: {gradient:.4f}")
print(f"Y-intercept of the line of best fit: {y_intercept:.4f}")
# Out:
# Gradient of the line of best fit: 1.8490
# Y-intercept of the line of best fit: -0.5398

# %%
n = gradient
f = 10**y_intercept * 2 * g * d / (4 * l)
print(f"n = {n}")
print(f"f = {f}")
# Out:
# n = 1.8489918553559606
# f = 0.0044225124080458506
